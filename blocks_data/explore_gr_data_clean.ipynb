# %%
import pathlib 
import pickle as pkl
import sys
sys.path.insert(0, "/home/estengel/real_good_robot")
from annotate_data import get_pairs, annotate_pairs, flip_pair


# data_home=pathlib.Path("/srv/local1/estengel/gr_data//2020-06-05-18-28-46_Real-Stack-SPOT-Trial-Reward-Masked-Testing")
# data_home=pathlib.Path("/srv/local1/estengel/gr_data/2020-06-07-16-31-33_Real-Stack-Two-Step-Reward-Masked-Testing")
# data_home=pathlib.Path("/srv/local1/estengel/gr_data/2020-06-07-18-10-48_Real-Rows-SPOT-Trial-Reward-Masked-Testing")
# data_home=pathlib.Path("/srv/local1/estengel/gr_data//2020-06-07-17-19-34_Real-Rows-Two-Step-Reward-Masked-Testing/")


data_home = pathlib.Path("/srv/local1/estengel/gr_data_sim/2021-02-13-16-43-06_Sim-Rows-Two-Step-Reward-Masked-Testing-Three-Step-History")

# %%
pairs = get_pairs(data_home, is_sim=True)
# pairs_with_actions = annotate_pairs(pairs, is_stack=False)
# Out:
# double grasp at 6
# double grasp at 17
# double grasp at 76
# double grasp at 103
# double grasp at 104
# double grasp at 105
# double grasp at 234
# double grasp at 272
# double grasp at 286
# double grasp at 319
# double grasp at 409
# double grasp at 433
# double grasp at 461
# double grasp at 489
# double grasp at 503
# double grasp at 520
# double grasp at 521
# double grasp at 608
# double grasp at 610
# double grasp at 612
# double grasp at 662
# double grasp at 672
# double grasp at 723
# double grasp at 725
# double grasp at 726
# double grasp at 728
# double grasp at 729
# double grasp at 748
# double grasp at 749
# double grasp at 762
# double grasp at 821
# double grasp at 828
# double grasp at 829
# double grasp at 879
# double grasp at 909
# double grasp at 942
# double grasp at 997
# double grasp at 1023
# double grasp at 1024
# double grasp at 1032
# double grasp at 1040
# double grasp at 1042
# double grasp at 1044

# %%
# with open(data_home.joinpath("with_actions.pkl"),"wb") as f1:
#     pkl.dump(pairs_with_actions, f1)

# with open(data_home.joinpath("with_actions.pkl"), "rb") as f1:
#     pairs_with_actions = pkl.load(f1)

# %%
for i in range(0, 10):
    test_p = pairs[i]
    test_p.show()
    print(test_p.generate())
    # next = input("next: ")
# test_p_1 = flip_pair(test_p, axis=1)
# test_p_1.show()
# test_p_1.generate()

# test_p_2 = flip_pair(test_p, axis=2)
# test_p_2.show()
# test_p_2.generate()

# test_p_3 = flip_pair(test_p, axis=3)
# test_p_3.show()
# test_p_3.generate()
# test_p_4 = flip_pair(test_p, axis=4)
# test_p_4.show()
# test_p_4.generate()
# Out:
# move the yellow block next to the red block
# move the green block next to the yellow block
# move the red block next to the blue block
# move the yellow block next to the blue block
# move the green block next to the blue block
# move the red block next to the green block
# move the green block next to the red block
# move the yellow block next to the green block
# move the yellow block next to the red block
# move the green block next to the blue block
